# %%
# !kill -9 -1

# %%
# !ls

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.plotly as py
import numpy as np
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Code to read csv file into colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#2. Get the file
downloadedTest = drive.CreateFile({'id':'1rGfRRaEqKAT0EwyF8uZRTDbfVBDajiE_'}) # replace the id with id of file you want to access
downloadedTest.GetContentFile('test.csv')  

downloadedTrain = drive.CreateFile({'id':'14rKrVfwK_Q0YeDnCknCF9N5Gz-m5502U'}) # replace the id with id of file you want to access
downloadedTrain.GetContentFile('train.csv')

downloadedValidation = drive.CreateFile({'id':'16kjxp9JOgUVExDHlcTGGS4eGjoYP6m0N'}) # replace the id with id of file you want to access
downloadedValidation.GetContentFile('validation.csv')


#3. Read file as panda dataframe
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')
validation = pd.read_csv('validation.csv')

# %%
#get seperation for comparison
mobileData=train[train.advertiser==2997]
milkData=train[train.advertiser==2259]
MobileData=mobileData.sort_values(by='hour')

# %%
#CTR Weekday:
mobile = mobileData[['click','weekday']]
milk = milkData[['click','weekday']]
#COUNT
Click1 = milk[milkWeekday.click==1]
pd.value_counts(Click1['weekday'])

# %%
#CTR Hour:
mobile = mobileData[['click','hour']]
milk = milkData[['click','hour']]
#COUNT
Click1 = mobile[mobile.click==1]
pd.value_counts(Click1['hour'])
# Out:
# 17    47
# 18    43
# 19    36
# 16    29
# 15    10
# 21    10
# 22     9
# 23     8
# 14     7
# 13     6
# 20     3
# 12     2
# 4      2
# 11     1
# 10     1
# 9      1
# 8      1
# 0      1
# Name: hour, dtype: int64

# %%
#CTR Region:
mobile = mobileData[['click','region']]
milk = milkData[['click','region']]
#COUNT
Click1 = milk[milk.click==1]
pd.value_counts(Click1['region'])
# Out:
# 216    43
# Name: region, dtype: int64

# %%
#CTR useragent(Browswer):
mobile = mobileData[['click','useragent']]
milk = milkData[['click','useragent']]
#COUNT
Click1 = milk[milk.click==1]
pd.value_counts(Click1['useragent'])
# Out:
# windows_ie        27
# windows_chrome    12
# windows_other      2
# android_safari     1
# linux_chrome       1
# Name: useragent, dtype: int64

# %%
#CTR useragent(Browswer):
mobile = mobileData[['click','slotwidth']]
milk = milkData[['click','slotwidth']]
#COUNT
Click1 = mobile[mobile.click==1]
pd.value_counts(Click1['slotwidth'])
# Out:
# 320    217
# Name: slotwidth, dtype: int64

# %%
#CTR useragent(Browswer):
mobile = mobileData[['click','adexchange']]
milk = milkData[['click','adexchange']]
mobile.head()
#COUNT
Click1 = mobile[mobile.click==1]
pd.value_counts(mobile['adexchange'])
# Out:
# Series([], Name: adexchange, dtype: int64)

# %%
mobile
# Out:
#          click  adexchange
# 93           0         NaN
# 125          0         NaN
# 150          0         NaN
# 183          0         NaN
# 197          0         NaN
# 316          0         NaN
# 329          0         NaN
# 453          0         NaN
# 532          0         NaN
# 533          0         NaN
# 602          0         NaN
# 782          0         NaN
# 898          0         NaN
# 916          0         NaN
# 942          0         NaN
# 957          0         NaN
# 1045         0         NaN
# 1058         0         NaN
# 1068         0         NaN
# 1075         0         NaN
# 1076         0         NaN
# 1092         0         NaN
# 1286         0         NaN
# 1405         0         NaN
# 1411         0         NaN
# 1491         0         NaN
# 1503         0         NaN
# 1542         0         NaN
# 1581         0         NaN
# 1635         0         NaN
# ...        ...         ...
# 2429497      0         NaN
# 2429519      0         NaN
# ...
